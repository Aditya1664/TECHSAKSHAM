# %%
import pandas as pd
import numpy as np

# %%
#numpy
"""
2-scalar
[1,2,3]-vector
[[1,2],[3,4]]-matrix
"""

#pandas
"""
1d-Series-homogeneous array, size-immutable
2d-dataframe-heterogeneously typed columns,size-mutable
"""
# Out:
# '\n1d-Series-homogeneous array, size-immutable\n2d-dataframe-heterogeneously typed columns,size-mutable\n'

# %%
#pandas.Series(data,index,dtype)

# %%
series=pd.Series([1,2,3,4,5])
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series1=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(series1)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
for i in series1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
series2=pd.Series(np.random.randn(5),index=['a','b','c','d','e'])
print(series2)
# Out:
# a   -0.676064
# b   -1.060520
# c   -0.037505
# d   -1.492667
# e    0.207414
# dtype: float64

# %%
z=pd.Series(np.random.rand(5),index=['a','b','c','d','e'])
print(z)
# Out:
# a    0.637252
# b    0.242372
# c    0.629906
# d    0.145148
# e    0.198526
# dtype: float64

# %%
dictionary={'a':1,'b':2,'c':3}
d1=pd.Series(dictionary)
print(d1)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
#[]-series
#[[]]-dataframe

# %%
#d1[[1,2]]
d1.iloc[[1,2]]
# Out:
# b    2
# c    3
# dtype: int64

# %%
series1+series2
# Out:
# a    0.323936
# b    0.939480
# c    2.962495
# d    2.507333
# e    5.207414
# dtype: float64

# %%
series+series1
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64

# %%
##empty dataframe
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame(columns=['c1','c2','c3'])
print(df)
# Out:
# Empty DataFrame
# Columns: [c1, c2, c3]
# Index: []

# %%
df=pd.DataFrame(columns=['c1','c2','c3','c4'],index=range(1,6))
print(df)
# Out:
#     c1   c2   c3   c4
# 1  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN

# %%
dictionary={'a':1,'b':2,'c':3}
pd.DataFrame([dictionary])
# Out:
#    a  b  c
# 0  1  2  3

# %%
df.index
# Out:
# RangeIndex(start=1, stop=6, step=1)

# %%
df.columns
# Out:
# Index(['c1', 'c2', 'c3', 'c4'], dtype='object')

# %%
mylist=[
['Apple','Red'],['Banana','Yellow'],['Orange','orange']]
mydata=pd.DataFrame(mylist)
print(mydata)
# Out:
#         0       1
# 0   Apple     Red
# 1  Banana  Yellow
# 2  Orange  orange

# %%
#dataframe using numpy array
mylist=np.array([
[0,1],[2,3],[4,5]])
mydf=pd.DataFrame(mylist,columns=['Even','Odd'])
print(mydf)
# Out:
#    Even  Odd
# 0     0    1
# 1     2    3
# 2     4    5

# %%
df=pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name') #it'll return a new datframe
#df.set_index('name',inplace=True) #it will modify the original dataframe
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
df.head()
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
df.tail()
# Out:
#                       name  calories  protein  vitamins     rating
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.describe()
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %%
#slicing rows using bracket operators
df[1:4]
# Out:
#                         name  calories  protein  vitamins     rating
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df['calories','rating'] #in single dimension we can't give multiple column names
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('calories', 'rating')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df['calories','rating']
#
# ...

# %%
df[['calories','rating']]
# Out:
#    calories     rating
# 0        70  68.402973
# 1       120  33.983679
# 2        70  59.425505
# 3        50  93.704912
# 4       110  34.384843
# 5       110  29.509541
# 6       110  33.174094
# 7       130  37.038562
# 8        90  49.120253
# 9        90  53.313813

# %%
#boolean filter
df1=df[0:5]
boolean_list=[True,False,True,True,False]
df1[boolean_list]
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df['calories']>70
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: calories, dtype: bool

# %%
condition=df['calories']>70
df[condition]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df[(df['calories']>70) & (df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 8                Bran Chex        90        2        25  49.120253

# %%
df[(df['calories']>70) | (df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.loc[2,'protein'] #returns in series format
# Out:
# 4

# %%
df.loc[0:4,['protein','name']]
# Out:
#    protein                       name
# 0        4                  100% Bran
# 1        3          100% Natural Bran
# 2        4                   All-Bran
# 3        4  All-Bran with Extra Fiber
# 4        2             Almond Delight

# %%
df.loc[[5],['protein']] #returns in dataframe format
# Out:
#    protein
# 5        2

# %%
df.loc[0:4,'name':'protein'] #more than one column will atomatically be considered as dataframe so need to specify in [].
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df.iloc[0:5,0:3]
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df.iloc[[0,2,4],0:3]
# Out:
#              name  calories  protein
# 0       100% Bran        70        4
# 2        All-Bran        70        4
# 4  Almond Delight       110        2

# %%
#add and delete rows and columns
df1.loc[4]=['Aditya',110,1,25,27.75]
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     Aditya       110        1        25  27.750000

# %%
df1=df.iloc[0:5,].copy()

# %%
df1.drop(3,axis=0,inplace=True)

# %%
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 4             Aditya       110        1        25  27.750000

# %%
df1.drop("name",axis=1)
# Out:
#    calories  protein  vitamins     rating
# 0        70        4        25  68.402973
# 1       120        3         0  33.983679
# 2        70        4        25  59.425505
# 4       110        1        25  27.750000

# %%
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 4             Aditya       110        1        25  27.750000

# %%
df1['My new column']=[1,2,3,4]
df1
# Out:
#                 name  calories  protein  vitamins     rating  My new column
# 0          100% Bran        70        4        25  68.402973              1
# 1  100% Natural Bran       120        3         0  33.983679              2
# 2           All-Bran        70        4        25  59.425505              3
# 4             Aditya       110        1        25  27.750000              4

# %%
ascending_df=df.sort_values(by='calories')

# %%
ascending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 4                     Aditya       110        1        25  27.750000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562

# %%
ascending_df=df.sort_values(by='calories',ascending=False)
ascending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 7                    Basic 4       130        3        25  37.038562
# 1          100% Natural Bran       120        3         0  33.983679
# 4                     Aditya       110        1        25  27.750000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df.columns=['col1','col2','col3','col4','col5']
df
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                     Aditya   110     1    25  27.750000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %%
df.to_csv('myfile.csv',index_label=False)

# %%
newdf=pd.read_csv('myfile.csv')
newdf
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                     Aditya   110     1    25  27.750000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %%
df2=df[5:8].copy()
df2
# Out:
#                       col1  col2  col3  col4       col5
# 5  Apple Cinnamon Cheerios   110     2    25  29.509541
# 6              Apple Jacks   110     2    25  33.174094
# 7                  Basic 4   130     3    25  37.038562

# %%
df2=df2.reset_index(drop=True)
df2
# Out:
#                       col1  col2  col3  col4       col5
# 0  Apple Cinnamon Cheerios   110     2    25  29.509541
# 1              Apple Jacks   110     2    25  33.174094
# 2                  Basic 4   130     3    25  37.038562

# %%
df1.drop('My new column',axis=1,inplace=True)
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 4             Aditya       110        1        25  27.750000

# %%
df1=df1.reset_index(drop=True)
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 3             Aditya       110        1        25  27.750000

# %%
pd.concat([df,df1],ignore_index=True)  #reset the index numbers
# Out:
#                          col1   col2  col3  col4       col5  \
# 0                   100% Bran   70.0   4.0  25.0  68.402973
# 1           100% Natural Bran  120.0   3.0   0.0  33.983679
# 2                    All-Bran   70.0   4.0  25.0  59.425505
# 3   All-Bran with Extra Fiber   50.0   4.0  25.0  93.704912
# 4                      Aditya  110.0   1.0  25.0  27.750000
# 5     Apple Cinnamon Cheerios  110.0   2.0  25.0  29.509541
# 6                 Apple Jacks  110.0   2.0  25.0  33.174094
# 7                     Basic 4  130.0   3.0  25.0  37.038562
# 8                   Bran Chex   90.0   2.0  25.0  49.120253
# 9                 Bran Flakes   90.0   3.0  25.0  53.313813
# 10                        NaN    NaN   NaN   NaN        NaN
# 11                        NaN    NaN   NaN   NaN        NaN
# 12                        NaN    NaN   NaN   NaN        NaN
# 13                        NaN    NaN   NaN   NaN        NaN
#
#                  name  calories  protein  vitamins     rating
# ...

# %%
data={'Gender':['female','male','female','male'],'Score':[86,89,67,90]}

#new_df=pd.DataFrame.from_dict(data)
new_df=pd.DataFrame(data)
new_df
# Out:
#    Gender  Score
# 0  female     86
# 1    male     89
# 2  female     67
# 3    male     90

# %%
group=new_df.groupby(new_df['Gender']).mean()
group
# Out:
#         Score
# Gender
# female   76.5
# male     89.5

# %%
from numpy import NaN

# %%
data1={'Name':['person1','person2','person3','person4'],'Age':[28,27,NaN,36]}

# %%
import pandas as pd
data=pd.DataFrame(data1)
data
# Out:
#       Name   Age
# 0  person1  28.0
# 1  person2  27.0
# 2  person3   NaN
# 3  person4  36.0

# %%
data.isnull().sum()
# Out:
# Name    0
# Age     1
# dtype: int64

# %%
data.dropna()
# Out:
#       Name   Age
# 0  person1  28.0
# 1  person2  27.0
# 3  person4  36.0

# %%
#data.dropna(inplace=True)

# %%
data['Age'].dtype
# Out:
# dtype('float64')

# %%
data2={'Name':['person1','person2','person3','person4'],'Age':[28,27,45,36]}

# %%
df=pd.DataFrame(data2)
df
# Out:
#       Name  Age
# 0  person1   28
# 1  person2   27
# 2  person3   45
# 3  person4   36

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
data['Age'].fillna(data['Age'].mean())
#data['Age'].fillna(data['Age'].mean(inplace=True))
# Out:
# 0    28.000000
# 1    27.000000
# 2    30.333333
# 3    36.000000
# Name: Age, dtype: float64

# %%
df=pd.DataFrame(data2)
df
# Out:
#       Name  Age
# 0  person1   28
# 1  person2   27
# 2  person3   45
# 3  person4   36

# %%
df['Age'].mode()[0]
# Out:
# 27

# %%
df['Age'].fillna(df['Age'].mode()[0])
# Out:
# 0    28
# 1    27
# 2    45
# 3    36
# Name: Age, dtype: int64

# %%
df['Age'].fillna(df['Age'].median())
# Out:
# 0    28
# 1    27
# 2    45
# 3    36
# Name: Age, dtype: int64
